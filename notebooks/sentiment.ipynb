# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

sys.path.insert(0, os.path.abspath("C://Users//pc//Desktop//Week 1//news_sentiment_analysis//src//"))

# %%
from src.data_loader import load_data
from src.sentiment_analysis import normalize_timestamps,adjust_news_to_trading_day,align_on_trading_day
from src.sentiment_analysis import align_news_to_trading_day,add_sentiment_score

print('Functions imported successfully!')
# Out:
# Functions imported successfully!

# %%
news_df = load_data('C:/Users/pc/Desktop/Week 1/news_sentiment_analysis/data/raw_analyst_ratings.csv')
news_df.head()
# Out:
#    unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                        date stock
# 0 2020-06-05 00:00:00+00:00     A
# 1 2020-06-03 00:00:00+00:00     A
# 2 2020-05-26 00:00:00+00:00     A
# ...

# %%
stock_df = load_data('C:/Users/pc/Desktop/Week 1/news_sentiment_analysis/data/AAPL.csv')
stock_df.head()
# Out:
#                        date     close      high       low      open  \
# 0 2009-01-02 00:00:00+00:00  2.721686  2.730385  2.554037  2.575630
# 1 2009-01-05 00:00:00+00:00  2.836553  2.884539  2.780469  2.794266
# 2 2009-01-06 00:00:00+00:00  2.789767  2.914229  2.770872  2.877641
# 3 2009-01-07 00:00:00+00:00  2.729484  2.774170  2.706990  2.753477
# 4 2009-01-08 00:00:00+00:00  2.780169  2.793666  2.700393  2.712090
#
#        volume
# 0   746015200
# 1  1181608400
# 2  1289310400
# 3   753048800
# 4   673500800

# %%
# normalize timestamps in both datasets
news_df = normalize_timestamps(news_df, "date")
stock_df = normalize_timestamps(stock_df, "date")

# %%
# Adjust news timestamps to align with trading days
news_df = adjust_news_to_trading_day(news_df, "date", cutoff_hour=16)

# %%
# align datasets
merged_df = align_on_trading_day(news_df, stock_df)

print(merged_df.head())
# Out:
#    unnamed: 0                                           headline  \
# 0           0            Stocks That Hit 52-Week Highs On Friday
# 1           1         Stocks That Hit 52-Week Highs On Wednesday
# 2           2                      71 Biggest Movers From Friday
# 3           3       46 Stocks Moving In Friday's Mid-Day Session
# 4           4  B of A Securities Maintains Neutral on Agilent...
#
#                                                  url          publisher  \
# 0  https://www.benzinga.com/news/20/06/16190091/s...  Benzinga Insights
# 1  https://www.benzinga.com/news/20/06/16170189/s...  Benzinga Insights
# 2  https://www.benzinga.com/news/20/05/16103463/7...         Lisa Levin
# 3  https://www.benzinga.com/news/20/05/16095921/4...         Lisa Levin
# 4  https://www.benzinga.com/news/20/05/16095304/b...         Vick Meyer
#
#                      date_x stock trading_day                    date_y  \
# ...

# %%
 # Align to trading days
aligned_news = align_news_to_trading_day(news_df,time_col="date",market="NYSE")

print(aligned_news.head())
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File pandas/_libs/tslibs/timestamps.pyx:566, in pandas._libs.tslibs.timestamps._Timestamp.__add__()
# --> 566 'Could not get source, probably due dynamically evaluated source code.'
#
# OverflowError: value too large
#
# The above exception was the direct cause of the following exception:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# Cell In[15], line 2
#       1  # Align to trading days
# ----> 2 aligned_news = align_news_to_trading_day(news_df,
#       3         time_col="date",
#       4         market="NYSE")
#       5
#
# File c:\Users\pc\Desktop\Week 1\news_sentiment_analysis\src\sentiment_analysis.py:69, in align_news_to_trading_day(news_df, time_col, market, start_date, end_date)
#      66     return next_day
#      68 # Apply mapping
# ...

# %%
# Apply sentiment analysis
news_with_sentiment = add_sentiment_score( news_df, text_column="headline")

print(news_with_sentiment.head())

# %%
# Apply sentiment analysis
sentiment_df = apply_all_sentiments(news_df,text_column="headline")

# Display results
print(sentiment_df.head())
