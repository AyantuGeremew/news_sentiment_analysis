# %%
import sys
import os

sys.path.insert(0, os.path.abspath("C://Users//pc//Desktop//Week 1//news_sentiment_analysis//src//data_loader.py"))

# %%
from src.data_loader import load_data
from src.analysis import get_length_stats,plot_length_distribution,print_summary

print('Functions imported successfully!')
print()
# Out:
# Functions imported successfully!

# %%
# Load the Amazon stock data
df = load_data('C:/Users/pc/Desktop/Week 1/news_sentiment_analysis/data/AMZN.csv')
df.head()
# Out:
# Loaded 3774 rows from 'C:/Users/pc/Desktop/Week 1/news_sentiment_analysis/data/AMZN.csv'
#             Close    High     Low    Open     Volume
# Date
# 2009-01-02  2.718  2.7265  2.5535  2.5675  145928000
# 2009-01-05  2.703  2.7870  2.6515  2.7865  190196000
# 2009-01-06  2.868  2.9110  2.6875  2.7275  221602000
# 2009-01-07  2.810  2.8475  2.7675  2.8145  158854000
# 2009-01-08  2.858  2.8660  2.7290  2.7495  131558000
