# %%
#import os
os.getcwd()
#os.chdir(r"C:/Users/pc/Desktop/Week 1/news_sentiment_analysis")

import sys
import os

sys.path.insert(0, os.path.abspath('r"C://Users//pc//Desktop//Week 1//news_sentiment_analysis//src//data_loader.py"'))

##print('Path set. Python will now look in:', os.path.abspath('r"C://Users//pc//Desktop//Week 1//news_sentiment_analysis'))

# %%
import matplotlib.pyplot as plt

from src.data_loader import load_data

print('Functions imported successfully!')
print()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 3
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 from src.data_loader import load_data
#       4
#       5 print('Functions imported successfully!')
#       6 print()
#
# ModuleNotFoundError: No module named 'src'

# %%
# Step 1: Load the data
df = load_data('../data/sample_stocks.csv')

# Step 2: Quick check
if df is not None:
    print(f"Columns available: {df.columns.tolist()}")
    display(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Step 1: Load the data
# ----> 2 df = load_data('../data/sample_stocks.csv')
#       3
#       4 # Step 2: Quick check
#       5 if df is not None:
#
# NameError: name 'load_data' is not defined

# %%
import src.data_loader
print(dir(src.data_loader))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
# Automatically get all CSV files in data folder
file_list = glob.glob("../data/*.csv")

    # Merge all files
df = merge_(file_list)

print(f"Merged dataset shape: {df.shape}")

# %%
# Basic statistics
stats = df["headline_length"].describe()
print("Headline Length Statistics")
print(stats)

# %%
# Additional statistics
print("\nMinimum Length:", df["headline_length"].min())
print("Maximum Length:", df["headline_length"].max())
print("Average Length:", df["headline_length"].mean())

# %%
# Plot distribution
plt.hist(df["headline_length"], bins=10)
plt.xlabel("Headline Character Count")
plt.ylabel("Frequency")
plt.title("Headline Length Distribution")

plt.show()

# %%
# Count articles per publisher
publisher_counts = df["publisher"].value_counts()
# Display results
print("Articles Per Publisher")
print(publisher_counts)

# %%
# Convert to DataFrame (optional)
publisher_df = publisher_counts.reset_index()
publisher_df.columns = ["Publisher", "Article_Count"]

print("\nTop Active Publishers")
print(publisher_df.head())

# %%
# Plot publisher activity
publisher_counts.head(10).plot(kind="bar")

# %%
plt.xlabel("Publisher")
plt.ylabel("Number of Articles")
plt.title("Top Active Publishers")

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
